# %% [markdown]
# # 8. Transformer

# %% [markdown]
# --------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 1. What is Transformer and why it is used ?
#
# * Transformers are the deep learning model that use self-attention mechanisms to analyze and process natural language data.
# * They are the encoder-decoder models that can be used in seq2seq usecases. eg : Language translation.
# * Transformers have multi model capabilities.
# * transformers doesn't use RNN, LSTM, GRU.
# * We can send parallel data to the transformer, but in classical model like LSTM , we need to send in sequentially.
# * We can pass pass huge amount of data.
# * training of transformer is very much extensive.

# %% [markdown]
# BERT - Encoder Architecture
#
# GPT - Decoder Architecture

# %% [markdown]
# --------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 2. Encoder-Decoder vs Attention Mechanism vs Transformer
#
# Encoder-Decoder :
#
# * The words are sent one by one at each timestamp (Not Scalable)
# *  The context vector is not sufficient to represent entire sentence If the sentence Increases, Bleau score dcreasing when length increases.
#
# Attention Mechanism :
#
# * The words are sent one by one at each timestamp (Not Scalable)
# * Instead of single context, we provide additional context to our decoder, accuracy started increasing.
#
# Transformer :
#
# * It uses self attention module, which means all the words will be parallely sent to the encoder (Scalable)
# * It uses contextual embedding.
#
# ![image.png](attachment:91f33b5a-200e-4ff8-8912-6c662c7ff4bc.png)

# %% [markdown]
# --------------------------------------------------------------------------------------------------------

# %% [markdown]
# # 3. Architecture of Transformer

# %% [markdown]
# ![image.png](attachment:21ad8b16-3ea4-455e-9a8f-ab179821a452.png)

# %% [markdown]
# * It is a Encoder Decoder Architecture, Inside encoder you may have multiple encoders and same for decoders.
# * In the research paper " Attention is all you need " they have used 6 encoders and 6 decoders.
#
# ![image.png](attachment:84efd6e4-dce9-41d1-894a-a6ee7b74b2fd.png)

# %% [markdown]
# * The text will be passing from one encoder to another encoder (bottom to top)
# * Let's consider 2 encoder and 2 decoder..
#
# ![image.png](attachment:e3be97b6-8c55-41cb-8943-98dac9c63455.png)

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 1. Input Embedding / Output Embedding:
# * Convert a word into vectors, in this case its 512 dimension
# * The Embedding Technique used is Byte pair
#
# ![image.png](attachment:c34a4848-b70e-4ce5-abdb-ba7defedd166.png)

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 2. Positional Encoding:
# * Since all the vectors of all words are passed in the same time, we need to maintain that order. Positional Encoding is used to maintain the sequence of the data
# * So, the positional Encoding is added to the Vector embedding
# * Positional Encoding is calculated by
#
# ![image.png](attachment:6f90eef8-73df-415b-aff3-345c5b1d63ec.png)
#
# * odd position takes Sin formula and even position takes Cos formula
#
# ![image.png](attachment:94faf0bd-9014-4a27-9ea5-2de491b116ec.png)

# %% [markdown]
# ![image.png](attachment:b69af8b9-3e97-423b-8cea-854a514db214.png)

# %% [markdown]
# ![image.png](attachment:b255bd01-3233-4494-a666-365ae01fa633.png)

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 3. Multi-Head Attention

# %% [markdown]
# ![image.png](attachment:818d84d1-7f03-4f32-ab45-f7afd67a40aa.png)

# %% [markdown]
# ![image.png](attachment:311c849e-2117-4090-ad7d-ebd7cd545ae7.png)

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Encoder Architecture

# %% [markdown]
# ![image.png](attachment:165a7e07-a791-410f-8bc0-0df7bab7a022.png)

# %% [markdown]
# ####  STEPS:
#
# * The Input sentence is passed to the embedding layer and vectors are created for each word.
# * These vectors are passed parallely to the self attention layer which creates the contextual vectors, which has the contextual meaning with other words in the sentence.
# * These contextual vectors are passed to the feed forward neural network.
# * The output vector of the neural network is passed on to the next encoder..

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Self Attention

# %% [markdown]
# * Self Attention, also known as scaled dot-product attention, is a crucial mechanism in the transformer architecture that allows the model to weigh the importance of different tokens in the input sequence relative to each other.
#
# * The integral part of self attention is to convert the embedding into contextual embedding.

# %% [markdown]
# #### Query , Key, Value
#
# * In normal embedding like Word2Vec, the same vectors is given for similar words eg : Apple phone and Apple fruit, both apple gets same embeddings, which destroys the contextual meaning.. so we convert the embedding into contextual embedding using self attention.
#
# * Single head attention : single set pf k, q, v matrix
#
# * multi head attention : muktiple set of k, q, v matrix

# %% [markdown]
# ### why do we need multihead self attention
#
# 1. Helps to capture ambiguity inside the data. ( 1 sentence may have multiple perspective).. it helps to intepret one sentence in multiple way. eg: The chicken is ready to eat.
# 2. single attention was not able to understand the entire context of the data.

# %%
### Cross Attention
