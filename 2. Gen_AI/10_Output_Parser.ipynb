# %% [markdown]
# # Output Parser
#
# * An output parser is a tool that helps process and format the AI's response into a structured format, like JSON or key-value pairs or just the content.
#
# * It makes it easier to extract useful information from the AI's output for further use.
#
# Simple Explanation : You can decide what all should be in ouput eg: only content etc..
#
# Here you need not write response.content

# %% [markdown]
# --------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Without Output Parser

# %%
# To Import the .env file
import os
from dotenv import load_dotenv
load_dotenv()

# Import the API keys from .env file
os.environ['OPENAI_API_KEY'] = os.getenv("OPENAI_API_KEY") # Access OpenAI 
os.environ['LANGCHAIN_API_KEY'] = os.getenv("LANGCHAIN_API_KEY") # To Access Langsmith
os.environ['LANGCHAIN_TRACING_V2'] = "true" # To track the project in Langsmith
os.environ['LANGCHAIN_PROJECT'] = os.getenv("LANGCHAIN_PROJECT") # Get the name of the project.

#Import neccessary Libraries
from langchain_openai import ChatOpenAI #importing chatbot for OpenAI
from langchain_core.prompts import ChatPromptTemplate

# Create a LLM model
llm = ChatOpenAI(model="gpt-4o")

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an expert AI Engineer. Provide me answers based on the question"),  
        ("user", "{input}")  
    ]
)

# Combining prompt along with LLM that actually becomes chain.
chain = prompt|llm

# provide the input and invoke the chain
response = chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# content='Langsmith is a tool developed by LangChain, designed to streamline and enhance the development, testing, and deployment of applications powered by language models. It focuses on improving the productivity of developers and application teams by providing a suite of features such as robust testing capabilities, monitoring tools, and evaluation metrics for different language models. Langsmith enables more effective iteration and refinement of language model-based applications, making it easier to build reliable and scalable solutions. The platform is particularly useful in scenarios where real-world deployment requires rigorous testing and performance tracking to ensure optimal application behavior.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 111, 'prompt_tokens': 33, 'total_tokens': 144, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_eb9dce56a8', 'finish_reason': 'stop', 'logprobs': None} id='run-0fdbfb2c-16b1-4a87-ad82-20071ae14758-0' usage_metadata={'input_tokens': 33, 'output_tokens': 111, 'total_tokens': 144, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 1. stroutput Parser

# %%
from langchain_core.output_parsers import StrOutputParser

# Initialize the output parser
Output_parser = StrOutputParser()

# The input will go through the prompt, then LLM and then Output_parser
chain=prompt|llm|Output_parser

# provide the input and invoke the chain
response = chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response) # you need not write  ".content"
# Out:
# Langsmith is a tool designed to complement LangChain, a leading framework that facilitates the creation of applications using language models. It provides capabilities to help developers evaluate and monitor their language model-based applications more effectively. This includes features for testing, debugging, and deploying language models, as well as tools for assessing the performance and improving the reliability of these models in real-world applications. Langsmith helps developers streamline the process from model development to production deployment, ensuring that applications built with LangChain maintain high standards of quality and efficiency.
