# %% [markdown]
# # Introduction

# %% [markdown]
# * AI - Application which can do its own task without any human intervention
# * ML - It is a statistical tool to analyze the data , visualize , predict, forecast , cluster...
# * DL - Main aim is to memic the human brain.
# * DS - It is a part of everything AI,ML,DL

# %% [markdown]
# ![image.png](attachment:7506e2f3-b8aa-4316-996a-142e448df2d4.png)

# %% [markdown]
# * Generative AI is a subset of Deep learning

# %% [markdown]
# # Generative AI

# %% [markdown]
# Generative AI generates new data based on the training sample. Generative model can generate Image, text, audio, video etc., as output.

# %% [markdown]
# ##### Two major segments
# 1. Generative Unimodel
# 2. Generative Multimodel

# %% [markdown]
# To Know the Intelligence , Speed , Cost of Multiple GEn AI Models
#
# https://artificialanalysis.ai/
